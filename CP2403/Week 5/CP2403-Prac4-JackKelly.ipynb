# %% [markdown]
# # First Name : Jack
# # Last Name : Kelly

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
nesarc = pd.read_csv('nesarc.csv', low_memory=False)
pd.set_option('display.float_format', lambda x:'%f'%x)

# %% [markdown]
# # From Prac 1
# # Columns/Data used in Prac 1

# %%
nesarc['S2AQ5B'] = pd.to_numeric(nesarc['S2AQ5B'], errors='coerce') #convert variable to numeric
nesarc['S2AQ5D'] = pd.to_numeric(nesarc['S2AQ5D'], errors='coerce') #convert variable to numeric
nesarc['S2AQ5A'] = pd.to_numeric(nesarc['S2AQ5A'], errors='coerce') #convert variable to numeric
nesarc['S2BQ1B1'] = pd.to_numeric(nesarc['S2BQ1B1'], errors='coerce') #convert variable to numeric
nesarc['AGE'] = pd.to_numeric(nesarc['AGE'], errors='coerce') #convert variable to numeric

# %% [markdown]
# # From Prac 2
# # A subset of nesarc data, with the following criteria
# # Age from 26 to 50
# # Beer drinking status - S2AQ5A = Y

# %%
sub1=nesarc[(nesarc['AGE']>=26) & (nesarc['AGE']<=50) & (nesarc['S2AQ5A']==1)]
sub2=sub1.copy()

# %% [markdown]
# # From Prac 2
# # SETTING MISSING DATA

# %%
sub2['S2AQ5D']=sub2['S2AQ5D'].replace(99, np.nan)

sub2['S2AQ5B']=sub2['S2AQ5B'].replace(8, np.nan)
sub2['S2AQ5B']=sub2['S2AQ5B'].replace(9, np.nan)
sub2['S2AQ5B']=sub2['S2AQ5B'].replace(10, np.nan)
sub2['S2AQ5B']=sub2['S2AQ5B'].replace(99, np.nan)

sub2['S2BQ1B1']=sub2['S2BQ1B1'].replace(9, np.nan)

# %% [markdown]
# # From Prac 2
# # Recode data

# %%
recode2 = {1:30, 2:26, 3:14, 4:8, 5:4, 6:2.5, 7:1}
sub2['BEER_FEQMO']= sub2['S2AQ5B'].map(recode2)

recode3 = {2:0, 1:1}
sub2['S2BQ1B1']= sub2['S2BQ1B1'].map(recode3)

# %% [markdown]
# # From Prac 2
# # Create secondary variables

# %%
# A secondary variable multiplying the number of days beer consumed/month and the approx number of 
# beer consumed/day
sub2['NUMBEERMO_EST']=sub2['BEER_FEQMO'] * sub2['S2AQ5D']

# %% [markdown]
# # Draw a Line chart
# # Age vs Number of beer consumed per month (NUMBEERMO_EST)

# %% [markdown]
# # a) mean number of beer consumed
# # var = mean number of beers consumed a month, grouped by age

# %%
var = sub2.groupby(['AGE']).NUMBEERMO_EST.mean()
print(var)
# Out:
# AGE
# 26   23.701357
# 27   23.854545
# 28   30.035270
# 29   23.994949
# 30   24.170530
# 31   25.541033
# 32   25.678994
# 33   24.761017
# 34   23.143713
# 35   28.668478
# 36   26.813272
# 37   28.530387
# 38   26.414773
# 39   27.307122
# 40   31.571023
# 41   23.233788
# 42   31.877676
# 43   28.045455
# 44   37.279762
# 45   27.067241
# 46   31.727799
# 47   33.204918
# 48   33.655303
# 49   28.177778
# 50   28.995614
# Name: NUMBEERMO_EST, dtype: float64

# %%
fig = plt.figure()
#code for line chart
var.plot(kind = 'line')
# Out:
# <Axes: xlabel='AGE'>

# %% [markdown]
# # b) total number of beer consumed
# # var2 = sum number of beers consumed a month, grouped by age

# %%
var2 = sub2.groupby(['AGE']).NUMBEERMO_EST.sum()
print(var2)
# Out:
# AGE
# 26    5238.000000
# 27    6560.000000
# 28    7238.500000
# 29    7126.500000
# 30    7299.500000
# 31    8403.000000
# 32    8679.500000
# 33    7304.500000
# 34    7730.000000
# 35    7912.500000
# 36    8687.500000
# 37   10328.000000
# 38    9298.000000
# 39    9202.500000
# 40   11113.000000
# 41    6807.500000
# 42   10424.000000
# 43    8021.000000
# 44    9394.500000
# 45    7849.500000
# 46    8217.500000
# 47    8102.000000
# 48    8885.000000
# 49    6340.000000
# 50    6611.000000
# Name: NUMBEERMO_EST, dtype: float64

# %%
fig = plt.figure()
# code for line chart
var2.plot(kind = 'line')
# Out:
# <Axes: xlabel='AGE'>

# %% [markdown]
# # Draw a stacked Column Chart
# # x = age (AGE)
# # y = number of beers consumed per month (NUMBEERMO_EST)
# # stack is based on depedency on beer (S2BQ1B1)
#
# # var3 = mean number of beers consumed a month, grouped by age and beer depedency (S2BQ1B1)

# %%
var3 = sub2.groupby(['AGE', 'S2BQ1B1']).NUMBEERMO_EST.sum()
print(var3)
# Out:
# AGE  S2BQ1B1
# 26   0.000000    4225.500000
#      1.000000     949.000000
# 27   0.000000    6000.000000
#      1.000000     560.000000
# 28   0.000000    5542.500000
#      1.000000    1686.500000
# 29   0.000000    5363.500000
#      1.000000    1675.000000
# 30   0.000000    5942.500000
#      1.000000    1244.000000
# 31   0.000000    7185.500000
#      1.000000    1212.500000
# 32   0.000000    7352.500000
#      1.000000    1288.500000
# 33   0.000000    6279.000000
#      1.000000     901.500000
# 34   0.000000    6672.000000
#      1.000000    1039.500000
# 35   0.000000    7264.500000
#      1.000000     518.000000
# 36   0.000000    7190.000000
#      1.000000    1420.000000
# 37   0.000000    7765.000000
#      1.000000    2531.000000
# 38   0.000000    7962.000000
#      1.000000    1294.000000
# 39   0.000000    8519.000000
#      1.000000     667.500000
# 40   0.000000   10030.500000
#      1.000000    1022.500000
# 41   0.000000    6047.000000
#      1.000000     755.500000
# 42   0.000000    9352.500000
#      1.000000     986.500000
# 43   0.000000    7061.000000
#      1.000000     695.000000
# 44   0.000000    7711.500000
#      1.000000    1186.000000
# 45   0.000000    6839.000000
#      1.000000     865.500000
# 46   0.000000    7180.000000
#      1.000000     925.500000
# 47   0.000000    5938.500000
#      1.000000    1949.000000
# 48   0.000000    6971.500000
#      1.000000    1913.500000
# 49   0.000000    5799.500000
#      1.000000     491.000000
# 50   0.000000    5341.500000
#      1.000000    1230.500000
# Name: NUMBEERMO_EST, dtype: float64

# %%
# code for vertical stack chart
var3.unstack().plot(kind='bar', stacked=True,  color=['red','blue'], grid=False)
# Out:
# <Axes: xlabel='AGE'>

# %% [markdown]
# # Draw a horizontal stacked Column Chart
# # x = age (AGE)
# # y = number of beers consumed per month (NUMBEERMO_EST)
# # stack is based on depedency on  beer (S2BQ1B1)

# %%
# code for horizontal stack chart
var3.unstack().plot(kind='barh', stacked=True,  color=['red','blue'], grid=False)
# Out:
# <Axes: ylabel='AGE'>

# %% [markdown]
# # Draw a Pie Chart showing age (AGE) and total beer consumed a month (NUMBEERMO_EST)
# # hint use var2

# %%
print(var2)
# Out:
# AGE
# 26    5238.000000
# 27    6560.000000
# 28    7238.500000
# 29    7126.500000
# 30    7299.500000
# 31    8403.000000
# 32    8679.500000
# 33    7304.500000
# 34    7730.000000
# 35    7912.500000
# 36    8687.500000
# 37   10328.000000
# 38    9298.000000
# 39    9202.500000
# 40   11113.000000
# 41    6807.500000
# 42   10424.000000
# 43    8021.000000
# 44    9394.500000
# 45    7849.500000
# 46    8217.500000
# 47    8102.000000
# 48    8885.000000
# 49    6340.000000
# 50    6611.000000
# Name: NUMBEERMO_EST, dtype: float64

# %%
fig = plt.figure()

# code for pie chart
var2.plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='NUMBEERMO_EST'>

# %% [markdown]
# # Draw a Violin Plot for age (AGE) and income (S1Q10A)

# %% [markdown]
# # convert income (S1Q10A) to numeric

# %%
sub2['S1Q10A'] = pd.to_numeric(sub2['S1Q10A']) #convert variable to numeric

# %% [markdown]
# # Plot violin plot

# %%
fig = plt.figure()

#code for violin chart
sns.violinplot(x = 'AGE', y = 'S1Q10A', data = sub2)

plt.xlabel('Age')
plt.ylabel('Income')
# Out:
# Text(0, 0.5, 'Income')

# %% [markdown]
# # Draw a HeatMap for Ethnicity and Carton of Beer consumed per month, based on depedency on beer

# %% [markdown]
# # Rename Race - From Module 4

# %%
# you can rename categorical variable values for graphing if original values are not informative 
# first change the variable format to categorical if you haven’t already done so
sub2['ETHRACE2A'] = sub2['ETHRACE2A'].astype('category')

sub2['ETHRACE2A']=sub2['ETHRACE2A'].cat.rename_categories(["White", "Black", "NatAm", "Asian", "Hispanic"])

# %% [markdown]
# # Create a new variable DRINK_ADAY using DRINK_ADAY function provided

# %%
def DRINK_ADAY (row):
   if row['BEER_FEQMO'] >= 30 :
      return 1
   elif row['BEER_FEQMO'] < 30 :
      return 0
    
sub2['DRINK_ADAY'] = sub2.apply (lambda row: DRINK_ADAY (row),axis=1)

# %% [markdown]
# # Print the size of DRINK_ADAY, grouped by category

# %%
c4= sub2.groupby('DRINK_ADAY').size()
print(c4)
# Out:
# DRINK_ADAY
# 0.000000    6897
# 1.000000     417
# dtype: int64

# %% [markdown]
# # Draw bar chart to show relationship between race (ETHRACE2A) and DRINK_ADAY

# %%
# bivariate bar graph C->C
# %matplotlib inline

#code for bar chart
sns.catplot(x = 'ETHRACE2A', y = 'DRINK_ADAY', data = sub2, kind = 'bar', ci = None)

plt.xlabel('Ethnic Group')
plt.ylabel('Proportion of daily Beer Drinkers')
# Out:
# C:\Users\jckkl\AppData\Local\Temp\ipykernel_38620\2717644210.py:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.catplot(x = 'ETHRACE2A', y = 'DRINK_ADAY', data = sub2, kind = 'bar', ci = None)
# Text(30.67283950617282, 0.5, 'Proportion of daily Beer Drinkers')

# %% [markdown]
# # Make copy of just race (ETHRACE2A) and DRINK_ADAY

# %%
sub3 = sub2[['ETHRACE2A','DRINK_ADAY']].copy()
sub3.head()
# Out:
#    ETHRACE2A  DRINK_ADAY
# 1   Hispanic         NaN
# 8      White         NaN
# 12     Asian    0.000000
# 16     White         NaN
# 24  Hispanic         NaN

# %% [markdown]
# # Create pivot table of race (ETHRACE2A) and DRINK_ADAY

# %%
table = pd.pivot_table(sub3, index=['ETHRACE2A'], columns=['DRINK_ADAY'], aggfunc=np.size)
print(table)
# Out:
# DRINK_ADAY  0.000000  1.000000
# ETHRACE2A
# White           8312       456
# Black           1972       234
# NatAm            222        14
# Asian            374        16
# Hispanic        2914       114
# C:\Users\jckkl\AppData\Local\Temp\ipykernel_38620\3567440229.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   table = pd.pivot_table(sub3, index=['ETHRACE2A'], columns=['DRINK_ADAY'], aggfunc=np.size)

# %% [markdown]
# # Draw heat map

# %%
fig = plt.figure()
# code for heat map
sns.heatmap(table)
# Out:
# <Axes: xlabel='DRINK_ADAY', ylabel='ETHRACE2A'>

# %% [markdown]
# # Draw a bubble Chart

# %% [markdown]
# # Read in gapminder.csv

# %%
pd.set_option('display.float_format', lambda x:'%.2f'%x)

gapminder = pd.read_csv('gapminder.csv', low_memory=False)
gapminder.head()
# Out:
#        country   incomeperperson alcconsumption armedforcesrate  \
# 0  Afghanistan                              .03        .5696534
# 1      Albania  1914.99655094922           7.29       1.0247361
# 2      Algeria  2231.99333515006            .69        2.306817
# 3      Andorra  21943.3398976022          10.17
# 4       Angola  1381.00426770244           5.57       1.4613288
#
#   breastcancerper100th      co2emissions  femaleemployrate hivrate  \
# 0                 26.8          75944000  25.6000003814697
# 1                 57.4  223747333.333333  42.0999984741211
# 2                 23.5  2932108666.66667  31.7000007629394      .1
# 3
# 4                 23.1         248358000  69.4000015258789       2
#
#     internetuserate lifeexpectancy     oilperperson polityscore  \
# 0  3.65412162280064         48.673                            0
# 1  44.9899469578783         76.918                            9
# 2  12.5000733055148         73.131  .42009452521537           2
# 3                81
# 4  9.99995388324075         51.093                           -2
#
#   relectricperperson   suicideper100th        employrate urbanrate
# 0                     6.68438529968262  55.7000007629394     24.04
# 1   636.341383366604  7.69932985305786  51.4000015258789     46.72
# 2   590.509814347428   4.8487696647644              50.5     65.22
# 3                     5.36217880249023                       88.92
# 4   172.999227388199  14.5546770095825  75.6999969482422      56.7

# %% [markdown]
# # Convert internetuserate, urbanrate and incomeperperson to numeric

# %%
gapminder['internetuserate'] = pd.to_numeric(gapminder['internetuserate'], errors = 'coerce')
gapminder['urbanrate'] = pd.to_numeric(gapminder['urbanrate'], errors = 'coerce')
gapminder['incomeperperson'] = pd.to_numeric(gapminder['incomeperperson'], errors = 'coerce')

# %%
gapminder_clean=gapminder.dropna()

# %% [markdown]
# # Draw a bubble Chart
# # x = urbanrate
# # y = income per person
# # bubble size = internetuserate

# %%
# %matplotlib inline
fig = plt.figure()

#bubble plot code
plt.scatter(gapminder_clean['urbanrate'], gapminder['incomeperperson'], s = gapminder['internetuserate'])

plt.xlabel('Ubran Rate')
plt.ylabel('Income Per Person')

#THIS DIDN'T WORK - I TRIED AN ALTERNATE DROPNA TECHNIQUE, BUT THERES ALWAYS A MISMATCH IN SIZE
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[59], line 5
#       2 fig = plt.figure()
#       4 #bubble plot code
# ----> 5 plt.scatter(gapminder_clean['urbanrate'], gapminder['incomeperperson'], s = gapminder['internetuserate'])
#       7 plt.xlabel('Ubran Rate')
#       8 plt.ylabel('Income Per Person')
#
# File T:\Anaconda\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File T:\Anaconda\Lib\site-packages\matplotlib\pyplot.py:3948, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, data, **kwargs)
#    3928 @_copy_docstring_and_deprecators(Axes.scatter)
#    3929 def scatter(
#    3930     x: float | ArrayLike,
#    (...)   3946     **kwargs,
#    3947 ) -> PathCollection:
# -> 3948     __ret = gca().scatter(
#    3949         x,
#    3950         y,
#    3951         s=s,
#    3952         c=c,
#    3953         marker=marker,
#    3954         cmap=cmap,
#    3955         norm=norm,
#    3956         vmin=vmin,
#    3957         vmax=vmax,
#    3958         alpha=alpha,
#    3959         linewidths=linewidths,
#    3960         edgecolors=edgecolors,
#    3961         colorizer=colorizer,
#    3962         plotnonfinite=plotnonfinite,
#    3963         **({"data": data} if data is not None else {}),
#    3964         **kwargs,
#    3965     )
#    3966     sci(__ret)
#    3967     return __ret
#
# File T:\Anaconda\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File T:\Anaconda\Lib\site-packages\matplotlib\__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1521 @functools.wraps(func)
#    1522 def inner(ax, *args, data=None, **kwargs):
#    1523     if data is None:
# -> 1524         return func(
#    1525             ax,
#    1526             *map(cbook.sanitize_sequence, args),
#    1527             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529     bound = new_sig.bind(ax, *args, **kwargs)
#    1530     auto_label = (bound.arguments.get(label_namer)
#    1531                   or bound.kwargs.get(label_namer))
#
# File T:\Anaconda\Lib\site-packages\matplotlib\axes\_axes.py:4936, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, **kwargs)
#    4934 y = np.ma.ravel(y)
#    4935 if x.size != y.size:
# -> 4936     raise ValueError("x and y must be the same size")
#    4938 if s is None:
#    4939     s = (20 if mpl.rcParams['_internal.classic_mode'] else
#    4940          mpl.rcParams['lines.markersize'] ** 2.0)
#
# ValueError: x and y must be the same size
